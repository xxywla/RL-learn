# %%
import gym
# env: environment
env = gym.make('CartPole-v0')

state = env.reset() # 重置环境的状态
print(state) # 初始状态
action_space = env.action_space # 推车有几个动作？（向左推，向右推）
print(action_space) # 行动的维度
# Out:
# [ 0.03497696 -0.01758935  0.00840256  0.01316722]
# Discrete(2)
# Gym has been unmaintained since 2022 and does not support NumPy 2.0 amongst other critical functionality.
# Please upgrade to Gymnasium, the maintained drop-in replacement of Gym, or contact the authors of your software and request that they upgrade.
# See the migration guide at https://gymnasium.farama.org/introduction/migration_guide/ for additional information.
# /opt/homebrew/anaconda3/envs/rl_learn/lib/python3.12/site-packages/gym/envs/registration.py:593: UserWarning: WARN: The environment CartPole-v0 is out of date. You should consider upgrading to version `v1`.
#   logger.warn(
# /opt/homebrew/anaconda3/envs/rl_learn/lib/python3.12/site-packages/gym/core.py:317: DeprecationWarning: WARN: Initializing wrapper in old step API which returns one bool instead of two. It is recommended to set `new_step_api=True` to use new step API. This will be the default behaviour in future.
#   deprecation(
# /opt/homebrew/anaconda3/envs/rl_learn/lib/python3.12/site-packages/gym/wrappers/step_api_compatibility.py:39: DeprecationWarning: WARN: Initializing environment in old step API which returns one bool instead of two. It is recommended to set `new_step_api=True` to use new step API. This will be the default behaviour in future.
#   deprecation(

# %%
action = 0 # 或者 1
next_state, reward, done, info = env.step(action)
print(next_state)
# Out:
# [ 0.03462517 -0.2128308   0.00866591  0.30848938]
# /opt/homebrew/anaconda3/envs/rl_learn/lib/python3.12/site-packages/gym/utils/passive_env_checker.py:241: DeprecationWarning: `np.bool8` is a deprecated alias for `np.bool_`.  (Deprecated NumPy 1.24)
#   if not isinstance(terminated, (bool, np.bool8)):

# %%
import numpy as np
import gym
import time

env = gym.make('CartPole-v0')
state = env.reset()
done = False
action_desc = {0: "向左推", 1: "向右推"}
total_reward = 0.0
reward_list = []
gamma = 0.99

while not done:
	env.render()
	action = np.random.choice([0, 1])
	next_state, reward, done, info = env.step(action)
	print(f"采取动作： \
	       {action_desc.get(action, '未知动作')}，\
	       获得奖励：{reward}，\
	       转移到下一个状态：{next_state}")
	reward_list.append(reward)
	time.sleep(0.1)

# 逆序计算
for r in reward_list[::-1]:
    total_reward = r + gamma * total_reward

print('回报（收益）：', total_reward)
env.close()
# Out:
# /opt/homebrew/anaconda3/envs/rl_learn/lib/python3.12/site-packages/gym/core.py:49: DeprecationWarning: WARN: You are calling render method, but you didn't specified the argument render_mode at environment initialization. To maintain backward compatibility, the environment will render in human mode.
# If you want to render in human mode, initialize the environment in this way: gym.make('EnvName', render_mode='human') and don't call the render method.
# See here for more information: https://www.gymlibrary.ml/content/api/
#   deprecation(
# /opt/homebrew/anaconda3/envs/rl_learn/lib/python3.12/site-packages/pygame/pkgdata.py:25: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import resource_stream, resource_exists
# /opt/homebrew/anaconda3/envs/rl_learn/lib/python3.12/site-packages/gym/utils/passive_env_checker.py:241: DeprecationWarning: `np.bool8` is a deprecated alias for `np.bool_`.  (Deprecated NumPy 1.24)
#   if not isinstance(terminated, (bool, np.bool8)):
# /opt/homebrew/anaconda3/envs/rl_learn/lib/python3.12/site-packages/gym/core.py:49: DeprecationWarning: WARN: You are calling render method, but you didn't specified the argument render_mode at environment initialization. To maintain backward compatibility, the environment will render in human mode.
# If you want to render in human mode, initialize the environment in this way: gym.make('EnvName', render_mode='human') and don't call the render method.
# See here for more information: https://www.gymlibrary.ml/content/api/
#   deprecation(
# 采取动作： 	       向左推，	       获得奖励：1.0，	       转移到下一个状态：[-0.00748255 -0.15686293  0.02802204  0.25511312]
# 采取动作： 	       向右推，	       获得奖励：1.0，	       转移到下一个状态：[-0.01061981  0.03784795  0.0331243  -0.02860114]
# 采取动作： 	       向左推，	       获得奖励：1.0，	       转移到下一个状态：[-0.00986285 -0.15773298  0.03255228  0.27434608]
# 采取动作： 	       向左推，	       获得奖励：1.0，	       转移到下一个状态：[-0.01301751 -0.3533039   0.0380392   0.5771157 ]
# 采取动作： 	       向右推，	       获得奖励：1.0，	       转移到下一个状态：[-0.02008359 -0.1587352   0.04958151  0.29665464]
# 采取动作： 	       向左推，	       获得奖励：1.0，	       转移到下一个状态：[-0.02325829 -0.35452762  0.0555146   0.60455334]
# 采取动作： 	       向左推，	       获得奖励：1.0，	       转移到下一个状态：[-0.03034885 -0.5503802   0.06760567  0.9141925 ]
# 采取动作： 	       向左推，	       获得奖励：1.0，	       转移到下一个状态：[-0.04135645 -0.7463482   0.08588953  1.227334  ]
# 采取动作： 	       向右推，	       获得奖励：1.0，	       转移到下一个状态：[-0.05628341 -0.55243033  0.1104362   0.96274996]
# 采取动作： 	       向右推，	       获得奖励：1.0，	       转移到下一个状态：[-0.06733202 -0.35895166  0.1296912   0.7067022 ]
# 采取动作： 	       向左推，	       获得奖励：1.0，	       转移到下一个状态：[-0.07451106 -0.5556091   0.14382525  1.0372334 ]
# 采取动作： 	       向左推，	       获得奖励：1.0，	       转移到下一个状态：[-0.08562323 -0.7523193   0.16456991  1.371391  ]
# 采取动作： 	       向右推，	       获得奖励：1.0，	       转移到下一个状态：[-0.10066962 -0.559593    0.19199774  1.1343731 ]
# 采取动作： 	       向左推，	       获得奖励：1.0，	       转移到下一个状态：[-0.11186148 -0.75663674  0.2146852   1.4806088 ]
# 回报（收益）： 13.12541872310217
